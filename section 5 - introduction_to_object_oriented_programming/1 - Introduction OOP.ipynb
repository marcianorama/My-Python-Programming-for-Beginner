# %% [markdown]
# # Introduction OOP - Overview

# %% [markdown]
# ## Object Oriented Programming
# ### * Thinking about Objects
# ### * Class
# ### * Object
# ### * Data (state)
# ### * Action (behaviour)
# ### * Encapsulation
# ### * Abstraction

# %% [markdown]
# ## <u>Let's take an example and try and understand</u>
# ### how to think in term of Object Oriented Programming

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <u> Object Oriented Programming Terminology </u>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <u> Exercise </u>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### so think abount an online shopping system and then identify what are the different thing that are involved in creating an online shopping system then you can identify the objects
#
# ### can identify what kind of data that would be associated with each object , and also what kind of behaviour would be associated with each other object and the second one is much simpler exercise

# %% [markdown]
# ### so thing about a person class , think about what can be the data which can be present in that and also what are the actions that can be performed on it

# %% [markdown]
# ## Answer

# %% [markdown]
# ### Exercise 1
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 2
